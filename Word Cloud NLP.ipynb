# %%
from nltk.corpus import stopwords, reuters
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud
import re
import matplotlib.pyplot as plt

# Code to download wordnet corpora
import nltk
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\EAMA\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Get reuters stories where categories='gas'
ids = reuters.fileids(categories='')
corpus = [reuters.raw(i) for i in ids]

# %%
def process_text(doc):
    sw=set(stopwords.words('english'))
    regex=re.compile("[^a-zA-Z ]")
    re_clean=regex.sub('',doc)
    clean_words=word_tokenize(re_clean.lower())
    lemma=[]
    for j in clean_words:
        lemma.append(lemmatizer.lemmatize(j))
    clean_words_stop=[]
    for i in lemma:
        if i not in sw:
            clean_words_stop.append(i)
    return ' '.join(clean_words_stop)
    # YOUR CODE HERE'''

# %%
'''def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return ' '.join(output)'''

# %%
# Process text for wordcloud creation
big_string = ' '.join(corpus)
new_words = process_text(big_string)

# %%
new_words
# Out:
# 'finn canadian study mtbe production plant finland national oil company neste oy ltneoyhe said statement agreed canadian firm study feasibility building plant edmonton canada produce replacement lead petrol prospective plant would cost estimated mln canadian dlrs would produce methyl tertiary butyl ether mtbe raw material available locally said partner study neste oy celanese canada inc hoechst celanese corporation trade mountain pipe line company ltd vancouver bc edmonton site wa suitable raw material availability proximity pipeline transportation important capital operating advantage gained locating existing celanese canada site statement said partner would look feasibility plant producing tonne per annum mtbe octane enhancer replace tetra ethyl lead mtbe would targeted united state lead level gasoline lowered health concern statement added canadian lead limit currently time high u limit lead scheduled virtual elimination canada create canadian demand mtbe said finland neste oy whose turnover last year wa five billion dlrs ha extensive experience mtbe ha major investment mtbe plant saudi arabia edmonton alberta plant would scheduled go stream late statement said eia say distillate stock unchanged gasoline crude mln eia say distillate stock unchanged gasoline crude mln eia say distillate stock unchanged week distillate fuel stock held primary storage unchanged week ended april three mln barrel energy information administration eia said weekly petroleum status report department energy agency said gasoline stock barrel week mln barrel refinery crude oil stock rose mln barrel mln eia said residual fuel stock fell barrel mln barrel crude oil stock strategic petroleum reserve spr rose mln barrel mln total crude refined product spr stock rose mln barrel said recent u oil demand pct year ago u oil demand measured product supplied fell pct four week ended april three mln barrel per day bpd mln period year ago energy information administration eia said weekly petroleum status report energy department agency said distillate demand wa pct period mln bpd mln year earlier gasoline demand averaged mln bpd pct mln last year residual fuel demand wa mln bpd pct mln eia said far year distillate demand fell pct mln bpd mln gasoline demand wa mln bpd pct mln residual fuel demand fell pct mln bpd mln eia said yeartodate domestic crude output wa estimated mln bpd pct mln year ago gross crude import averaged mln bpd pct mln said exxon ltxon extends midgrade unleaded marketing exxon co usa said expanding marketing midgrade unleaded gasoline along u east coast exxon corp subsidiary said changeover octane unleaded fuel begin late month early next major market virginia maryland florida district columbia product wa introduced new york new jersey delaware connecticut rhode island massachusetts new hampshire philadelphia area late last year singapore oil company set pump price singapore oil company set petrol diesel price pump today subject ceiling determined individual wholesale price ministry trade industry said ministry previously revised pump price announced change oil company lead content petrol cut gmlitre gm today pump price lower lead petrol grade expected announced soon oil company said wholesale price centslitre cent higher previous grade singapore petroleum co revise petrol pump price singapore petroleum co pte ltd revise pump price petrol june official said grade octane gmlead centslitre cent previously gm lead grade octane cent previously spcs price revision follows ministry trade industry move liberalise petrol pricing allowing oil company set pump price new grade petrol lower lead content sold singapore today line ministry environment regulation mobil raise singapore petrol pump price mobil oil singapore pte lte raise pump price petrol june spokeswoman said grade octane gm lead centslitre cent previously gm lead grade octane cent previously spc earlier announced pump price cent cent octane respectively gm lead petrol sold singapore today li ...

# %%
# Generate wordcloud
wc = WordCloud().generate(new_words)
plt.imshow(wc)

# %%
from nltk.util import ngrams

# %%
def process_text_bg(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    sw_words = [word.lower() for word in lem if word.lower() not in sw]
    bigrams = ngrams(sw_words, 2)
    output = ['_'.join(i) for i in bigrams]
    return ' '.join(output)

# %%
# Process text for wordcloud creation
input_bigrams = process_text_bg(big_string)

# %%
# Generate wordcloud
wc = WordCloud().generate(input_bigrams)
plt.imshow(wc)
